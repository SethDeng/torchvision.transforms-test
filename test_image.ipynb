# %%
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
img = Image.open("test/girl.jpg")
print("original_size：",img.size)
data1 = transforms.RandomResizedCrop(224)(img)
print("random_crop_size: ",data1.size)
data2 = transforms.RandomResizedCrop(224)(img)
data3 = transforms.RandomResizedCrop(224)(img)

plt.imshow(img),plt.title("original")
plt.show()
plt.imshow(data1),plt.title("img1")
plt.show()
plt.imshow(data2),plt.title("img1")
plt.show()
plt.imshow(data3),plt.title("img1")
plt.show()
# Out:
# original_size： (1024, 1774)
# random_crop_size:  (224, 224)
