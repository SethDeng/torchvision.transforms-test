# %%
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
img = Image.open("test/girl.jpg")
print("original_size：",img.size)
img1 = transforms.RandomResizedCrop(224)(img)
print("random_crop_size: ",img1.size)
img2 = transforms.RandomResizedCrop(224)(img)
img3 = transforms.RandomResizedCrop(224)(img)

plt.imshow(img),plt.title("original")
plt.show()
plt.imshow(img1),plt.title("img1")
plt.show()
plt.imshow(img2),plt.title("img2")
plt.show()
plt.imshow(img3),plt.title("img3")
plt.show()
# Out:
# original_size： (1024, 1774)
# random_crop_size:  (224, 224)
